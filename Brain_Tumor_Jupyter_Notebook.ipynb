# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2025.8.3)
# Requirement already satisfied: charset-normalizer in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (3.10)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kaggle
#
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    ---------------------------------------- 5/5 [kaggle]
#
# Successfully installed kaggle-1.7.4.5 protobuf-6.32.0 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = r"C:\Users\Shruti\.kaggle"

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): CC0-1.0
# brain-tumor-mri-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -q brain-tumor-mri-dataset.zip -d ./data

# %%
pip install tensorflow keras seaborn scikit-learn matplotlib
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting keras
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.74.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.3.1)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.2.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: rich in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from keras) (14.0.0)
# Collecting namex (from keras)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras)
#   Downloading optree-0.17.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.0)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shruti\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/332.0 MB 5.7 MB/s eta 0:00:58
#    ---------------------------------------- 1.8/332.0 MB 5.0 MB/s eta 0:01:06
#    ---------------------------------------- 3.1/332.0 MB 5.3 MB/s eta 0:01:02
#     --------------------------------------- 5.0/332.0 MB 6.0 MB/s eta 0:00:55
#     --------------------------------------- 6.3/332.0 MB 6.5 MB/s eta 0:00:51
#     --------------------------------------- 7.1/332.0 MB 6.0 MB/s eta 0:00:54
#     --------------------------------------- 7.9/332.0 MB 5.6 MB/s eta 0:00:58
#    - -------------------------------------- 8.7/332.0 MB 5.4 MB/s eta 0:01:01
#    - -------------------------------------- 9.2/332.0 MB 5.1 MB/s eta 0:01:04
#    - -------------------------------------- 9.4/332.0 MB 4.5 MB/s eta 0:01:12
0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  329.3/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  329.5/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  330.0/332.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  330.6/332.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  331.1/332.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  331.9/332.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 332.0/332.0 MB 3.4 MB/s eta 0:00:00
# Downloading grpcio-1.74.0-cp313-cp313-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.5 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 1.6/4.5 MB 3.6 MB/s eta 0:00:01
#    --------------------- ------------------ 2.4/4.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.1/4.5 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.9/4.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 3.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl (208 kB)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.5 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 1.3/5.5 MB 3.2 MB/s eta 0:00:02
#    --------------- ------------------------ 2.1/5.5 MB 3.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 3.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------- ----------------- 0.8/1.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.7 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 5.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/8.7 MB 6.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 6.0 MB/s eta 0:00:01
#    -------------------- ------------------- 4.5/8.7 MB 6.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.7 MB 5.7 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 5.7 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# ...
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    ---------------------------------------- 26/26 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google_pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 joblib-1.5.2 keras-3.11.3 libclang-18.1.1 markdown-3.8.2 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 scikit-learn-1.7.1 scipy-1.16.1 seaborn-0.13.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 threadpoolctl-3.6.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25891 sha256=0ae08175d8941340738d4a01b01eb6ab39a1bac8b626d88e7d57943c5442dd2e
#   Stored in directory: c:\users\shruti\appdata\local\pip\cache\wheels\69\2c\66\f966db29490794305257ac3abfe71d4f963f5fc75ba0eb8eb7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'imutils' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'imutils'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install colab
# Out:
# Collecting colab
#   Downloading colab-1.13.5.tar.gz (567 kB)
#      ---------------------------------------- 0.0/567.7 kB ? eta -:--:--
#      ------------------ --------------------- 262.1/567.7 kB ? eta -:--:--
#      -------------------------------------- 567.7/567.7 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   C:\Users\Shruti\AppData\Local\Programs\Python\Python313\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#     warnings.warn(msg)
#   C:\Users\Shruti\AppData\Local\Programs\Python\Python313\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'test_suite'
#     warnings.warn(msg)
#   error in colab setup command: 'install_requires' must be a string or iterable of strings containing valid project/version requirement specifiers; Expected end or semicolon (after version specifier)
#       pytz>=2011n
#           ~~~~~~^
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement google.colab (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for google.colab

# %%
import tensorflow
from PIL import Image
import glob
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img, save_img, img_to_array
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization,Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation,GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,EarlyStopping
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np
from tqdm import tqdm
from sklearn.utils import shuffle
import cv2
import os
import shutil
import itertools
import imutils
from sklearn.model_selection import StratifiedKFold
import random
from tensorflow.keras import layers

# %%
data_dir = ('C:/Users/Shruti/Downloads/brain_tumor/Training')
categories = ['glioma', 'meningioma', 'notumor', 'pituitary']
plt.figure(figsize=(20, 16))

images_path = ['/glioma/Tr-glTr_0000.jpg', '/meningioma/Tr-meTr_0000.jpg', '/notumor/Tr-noTr_0000.jpg', '/pituitary/Tr-piTr_0000.jpg']

for i in range(4):
    ax = plt.subplot(2, 2, i + 1)
    img = cv2.imread(data_dir + images_path[i])
    img = cv2.resize(img, (224, 224))
    plt.imshow(img)
    plt.title(categories[i])

# %% [markdown]
# croping images

# %%
import numpy as np
from tqdm import tqdm
import cv2
import os
import imutils

# %%
def crop_img(img):
	"""
	Finds the extreme points on the image and crops the rectangular out of them
	"""
	gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
	gray = cv2.GaussianBlur(gray, (3, 3), 0)

	# threshold the image, then perform a series of erosions +
	# dilations to remove any small regions of noise
	thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
	thresh = cv2.erode(thresh, None, iterations=2)
	thresh = cv2.dilate(thresh, None, iterations=2)

	# find contours in thresholded image, then grab the largest one
	cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
	cnts = imutils.grab_contours(cnts)
	c = max(cnts, key=cv2.contourArea)

	# find the extreme points
	extLeft = tuple(c[c[:, :, 0].argmin()][0])
	extRight = tuple(c[c[:, :, 0].argmax()][0])
	extTop = tuple(c[c[:, :, 1].argmin()][0])
	extBot = tuple(c[c[:, :, 1].argmax()][0])
	ADD_PIXELS = 0
	new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

	return new_img

# %%
if __name__ == "__main__":
	training = "C:/Users/Shruti/Downloads/brain_tumor/Training"
	testing = "C:/Users/Shruti/Downloads/brain_tumor/Testing"
	training_dir = os.listdir(training)
	testing_dir = os.listdir(testing)
	IMG_SIZE = 256

	for dir in training_dir:
		save_path = 'C:/Users/Shruti/Downloads/brain_tumor/cropped/Training/'+ dir
		path = os.path.join(training,dir)
		image_dir = os.listdir(path)
		for img in image_dir:
			image = cv2.imread(os.path.join(path,img))
			new_img = crop_img(image)
			new_img = cv2.resize(new_img,(IMG_SIZE,IMG_SIZE))
			if not os.path.exists(save_path):
				os.makedirs(save_path)
			cv2.imwrite(save_path+'/'+img, new_img)

	for dir in testing_dir:
		save_path = 'C:/Users/Shruti/Downloads/brain_tumor/cropped/Testing/'+ dir
		path = os.path.join(testing,dir)
		image_dir = os.listdir(path)
		for img in image_dir:
			image = cv2.imread(os.path.join(path,img))
			new_img = crop_img(image)
			new_img = cv2.resize(new_img,(IMG_SIZE,IMG_SIZE))
			if not os.path.exists(save_path):
				os.makedirs(save_path)
			cv2.imwrite(save_path+'/'+img, new_img)

# %%
img = cv2.imread('C:/Users/Shruti/Downloads/brain_tumor/Training/meningioma/Tr-meTr_0000.jpg')
img = cv2.resize(
            img,
            dsize=(224,224),
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
labels = ['glioma', 'meningioma', 'notumor', 'pituitary']

x_train = [] # training images.
y_train  = [] # training labels.
x_test = [] # testing images.
y_test = [] # testing labels.

image_size = 200


for label in labels:
    trainPath = os.path.join('C:/Users/Shruti/Downloads/brain_tumor/cropped/Training',label)
    for file in tqdm(os.listdir(trainPath)):
        image = cv2.imread(os.path.join(trainPath, file),0) # load images in gray.
        image = cv2.bilateralFilter(image, 2, 50, 50) # remove images noise.
        image = cv2.applyColorMap(image, cv2.COLORMAP_BONE) # produce a pseudocolored image.
        image = cv2.resize(image, (image_size, image_size)) # resize images into 150*150.
        x_train.append(image)
        y_train.append(labels.index(label))

    testPath = os.path.join('C:/Users/Shruti/Downloads/brain_tumor/cropped/Testing',label)
    for file in tqdm(os.listdir(testPath)):
        image = cv2.imread(os.path.join(testPath, file),0)
        image = cv2.bilateralFilter(image, 2, 50, 50)
        image = cv2.applyColorMap(image, cv2.COLORMAP_BONE)
        image = cv2.resize(image, (image_size, image_size))
        x_test.append(image)
        y_test.append(labels.index(label))


x_train = np.array(x_train) / 255.0 # normalize Images into range 0 to 1.
x_test = np.array(x_test) / 255.0

print(x_train.shape)
print(x_test.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1321/1321 [00:05<00:00, 229.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 230.28it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1339/1339 [00:05<00:00, 227.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 306/306 [00:01<00:00, 230.37it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1595/1595 [00:07<00:00, 219.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 405/405 [00:01<00:00, 226.26it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1457/1457 [00:06<00:00, 228.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 224.18it/s]
# (5712, 200, 200, 3)
# (1311, 200, 200, 3)

# %%
images = [x_train[i] for i in range(15)]
fig, axes = plt.subplots(3, 5, figsize = (10, 10))
axes = axes.flatten()
for img, ax in zip(images, axes):
    ax.imshow(img)
plt.tight_layout()
plt.show()

# %%
x_train, y_train = shuffle(x_train,y_train, random_state=42)

y_train = tensorflow.keras.utils.to_categorical(y_train) #One Hot Encoding on the labels
y_test = tensorflow.keras.utils.to_categorical(y_test)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42) #Dividing the dataset into Training and Validation sets.

print(x_val.shape)
# Out:
# (1143, 200, 200, 3)

# %%
# set the paramters we want to change randomly
demo_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    rescale=1./255,
    zoom_range=0.2,
    shear_range=0.05,
    brightness_range=[0.1, 1.5],
    horizontal_flip=True,
    vertical_flip=True
)



x = x_train[0]
x = x.reshape((1,) + x.shape)

i = 0
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview_2', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
plt.imshow(x[0])
plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

plt.figure(figsize=(15,6))
i = 1
for img in os.listdir('preview_2/'):
    img = cv2.imread('preview_2/' + img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(3,7,i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i > 3*7:
        break
plt.suptitle('Augemented Images')
plt.show()

# %%
# ImageDataGenerator transforms each image in the batch by a series of random translations, rotations, etc.
datagen = ImageDataGenerator(
     rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True)

# After you have created and configured your ImageDataGenerator, you must fit it on your data.
datagen.fit(x_train)

# %%
from tensorflow.keras.applications.resnet import ResNet50
IMG_SIZE=(200,200)
conv_base = ResNet50(
    include_top=False,
    input_shape=IMG_SIZE + (3,),
    weights='imagenet')

for layer in conv_base.layers:
    layer.trainable = True

# %%
model = conv_base.output
model = GlobalAveragePooling2D()(model)
model = Dropout(0.4)(model)
model = Dense(4, activation="softmax")(model)
model = Model(inputs= conv_base.input, outputs= model)

#compile our model.
adam = Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss = 'categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 200, 200, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1_pad (ZeroPadding2D)     │ (None, 206, 206, 3)       │               0 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1_conv (Conv2D)           │ (None, 100, 100, 64)      │           9,472 │ conv1_pad[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1_bn (BatchNormalization) │ (None, 100, 100, 64)      │             256 │ conv1_conv[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1_relu (Activation)       │ (None, 100, 100, 64)      │               0 │ conv1_bn[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ pool1_pad (ZeroPadding2D)     │ (None, 102, 102, 64)      │               0 │ conv1_relu[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ pool1_pool (MaxPooling2D)     │ (None, 50, 50, 64)        │               0 │ pool1_pad[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_1_conv (Conv2D)  │ (None, 50, 50, 64)        │           4,160 │ pool1_pool[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_1_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block1_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_1_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block1_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_2_conv (Conv2D)  │ (None, 50, 50, 64)        │          36,928 │ conv2_block1_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_2_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block1_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_2_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block1_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_0_conv (Conv2D)  │ (None, 50, 50, 256)       │          16,640 │ pool1_pool[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_3_conv (Conv2D)  │ (None, 50, 50, 256)       │          16,640 │ conv2_block1_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_0_bn             │ (None, 50, 50, 256)       │           1,024 │ conv2_block1_0_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_3_bn             │ (None, 50, 50, 256)       │           1,024 │ conv2_block1_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_add (Add)        │ (None, 50, 50, 256)       │               0 │ conv2_block1_0_bn[0][0],   │
# │                               │                           │                 │ conv2_block1_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block1_out (Activation) │ (None, 50, 50, 256)       │               0 │ conv2_block1_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_1_conv (Conv2D)  │ (None, 50, 50, 64)        │          16,448 │ conv2_block1_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_1_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block2_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_1_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block2_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_2_conv (Conv2D)  │ (None, 50, 50, 64)        │          36,928 │ conv2_block2_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_2_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block2_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_2_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block2_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_3_conv (Conv2D)  │ (None, 50, 50, 256)       │          16,640 │ conv2_block2_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_3_bn             │ (None, 50, 50, 256)       │           1,024 │ conv2_block2_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_add (Add)        │ (None, 50, 50, 256)       │               0 │ conv2_block1_out[0][0],    │
# │                               │                           │                 │ conv2_block2_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block2_out (Activation) │ (None, 50, 50, 256)       │               0 │ conv2_block2_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_1_conv (Conv2D)  │ (None, 50, 50, 64)        │          16,448 │ conv2_block2_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_1_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block3_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_1_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block3_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_2_conv (Conv2D)  │ (None, 50, 50, 64)        │          36,928 │ conv2_block3_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_2_bn             │ (None, 50, 50, 64)        │             256 │ conv2_block3_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_2_relu           │ (None, 50, 50, 64)        │               0 │ conv2_block3_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_3_conv (Conv2D)  │ (None, 50, 50, 256)       │          16,640 │ conv2_block3_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_3_bn             │ (None, 50, 50, 256)       │           1,024 │ conv2_block3_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_add (Add)        │ (None, 50, 50, 256)       │               0 │ conv2_block2_out[0][0],    │
# │                               │                           │                 │ conv2_block3_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2_block3_out (Activation) │ (None, 50, 50, 256)       │               0 │ conv2_block3_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_1_conv (Conv2D)  │ (None, 25, 25, 128)       │          32,896 │ conv2_block3_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_1_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block1_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_1_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block1_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_2_conv (Conv2D)  │ (None, 25, 25, 128)       │         147,584 │ conv3_block1_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_2_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block1_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_2_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block1_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_0_conv (Conv2D)  │ (None, 25, 25, 512)       │         131,584 │ conv2_block3_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_3_conv (Conv2D)  │ (None, 25, 25, 512)       │          66,048 │ conv3_block1_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_0_bn             │ (None, 25, 25, 512)       │           2,048 │ conv3_block1_0_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_3_bn             │ (None, 25, 25, 512)       │           2,048 │ conv3_block1_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_add (Add)        │ (None, 25, 25, 512)       │               0 │ conv3_block1_0_bn[0][0],   │
# │                               │                           │                 │ conv3_block1_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block1_out (Activation) │ (None, 25, 25, 512)       │               0 │ conv3_block1_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_1_conv (Conv2D)  │ (None, 25, 25, 128)       │          65,664 │ conv3_block1_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_1_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block2_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_1_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block2_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_2_conv (Conv2D)  │ (None, 25, 25, 128)       │         147,584 │ conv3_block2_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_2_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block2_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_2_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block2_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_3_conv (Conv2D)  │ (None, 25, 25, 512)       │          66,048 │ conv3_block2_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_3_bn             │ (None, 25, 25, 512)       │           2,048 │ conv3_block2_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_add (Add)        │ (None, 25, 25, 512)       │               0 │ conv3_block1_out[0][0],    │
# │                               │                           │                 │ conv3_block2_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block2_out (Activation) │ (None, 25, 25, 512)       │               0 │ conv3_block2_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_1_conv (Conv2D)  │ (None, 25, 25, 128)       │          65,664 │ conv3_block2_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_1_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block3_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_1_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block3_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_2_conv (Conv2D)  │ (None, 25, 25, 128)       │         147,584 │ conv3_block3_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_2_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block3_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_2_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block3_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_3_conv (Conv2D)  │ (None, 25, 25, 512)       │          66,048 │ conv3_block3_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_3_bn             │ (None, 25, 25, 512)       │           2,048 │ conv3_block3_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_add (Add)        │ (None, 25, 25, 512)       │               0 │ conv3_block2_out[0][0],    │
# │                               │                           │                 │ conv3_block3_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block3_out (Activation) │ (None, 25, 25, 512)       │               0 │ conv3_block3_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_1_conv (Conv2D)  │ (None, 25, 25, 128)       │          65,664 │ conv3_block3_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_1_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block4_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_1_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block4_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_2_conv (Conv2D)  │ (None, 25, 25, 128)       │         147,584 │ conv3_block4_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_2_bn             │ (None, 25, 25, 128)       │             512 │ conv3_block4_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_2_relu           │ (None, 25, 25, 128)       │               0 │ conv3_block4_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_3_conv (Conv2D)  │ (None, 25, 25, 512)       │          66,048 │ conv3_block4_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_3_bn             │ (None, 25, 25, 512)       │           2,048 │ conv3_block4_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_add (Add)        │ (None, 25, 25, 512)       │               0 │ conv3_block3_out[0][0],    │
# │                               │                           │                 │ conv3_block4_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3_block4_out (Activation) │ (None, 25, 25, 512)       │               0 │ conv3_block4_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         131,328 │ conv3_block4_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block1_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block1_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block1_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block1_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block1_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_0_conv (Conv2D)  │ (None, 13, 13, 1024)      │         525,312 │ conv3_block4_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block1_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_0_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block1_0_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block1_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block1_0_bn[0][0],   │
# │                               │                           │                 │ conv4_block1_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block1_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block1_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         262,400 │ conv4_block1_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block2_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block2_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block2_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block2_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block2_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block2_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block2_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block1_out[0][0],    │
# │                               │                           │                 │ conv4_block2_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block2_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block2_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         262,400 │ conv4_block2_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block3_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block3_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block3_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block3_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block3_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block3_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block3_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block2_out[0][0],    │
# │                               │                           │                 │ conv4_block3_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block3_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block3_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         262,400 │ conv4_block3_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block4_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block4_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block4_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block4_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block4_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block4_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block4_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block3_out[0][0],    │
# │                               │                           │                 │ conv4_block4_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block4_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block4_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         262,400 │ conv4_block4_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block5_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block5_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block5_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block5_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block5_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block5_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block5_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block4_out[0][0],    │
# │                               │                           │                 │ conv4_block5_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block5_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block5_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_1_conv (Conv2D)  │ (None, 13, 13, 256)       │         262,400 │ conv4_block5_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_1_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block6_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_1_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block6_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_2_conv (Conv2D)  │ (None, 13, 13, 256)       │         590,080 │ conv4_block6_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_2_bn             │ (None, 13, 13, 256)       │           1,024 │ conv4_block6_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_2_relu           │ (None, 13, 13, 256)       │               0 │ conv4_block6_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_3_conv (Conv2D)  │ (None, 13, 13, 1024)      │         263,168 │ conv4_block6_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_3_bn             │ (None, 13, 13, 1024)      │           4,096 │ conv4_block6_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_add (Add)        │ (None, 13, 13, 1024)      │               0 │ conv4_block5_out[0][0],    │
# │                               │                           │                 │ conv4_block6_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv4_block6_out (Activation) │ (None, 13, 13, 1024)      │               0 │ conv4_block6_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_1_conv (Conv2D)  │ (None, 7, 7, 512)         │         524,800 │ conv4_block6_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_1_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block1_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_1_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block1_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_2_conv (Conv2D)  │ (None, 7, 7, 512)         │       2,359,808 │ conv5_block1_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_2_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block1_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_2_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block1_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_0_conv (Conv2D)  │ (None, 7, 7, 2048)        │       2,099,200 │ conv4_block6_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_3_conv (Conv2D)  │ (None, 7, 7, 2048)        │       1,050,624 │ conv5_block1_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_0_bn             │ (None, 7, 7, 2048)        │           8,192 │ conv5_block1_0_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_3_bn             │ (None, 7, 7, 2048)        │           8,192 │ conv5_block1_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_add (Add)        │ (None, 7, 7, 2048)        │               0 │ conv5_block1_0_bn[0][0],   │
# │                               │                           │                 │ conv5_block1_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block1_out (Activation) │ (None, 7, 7, 2048)        │               0 │ conv5_block1_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_1_conv (Conv2D)  │ (None, 7, 7, 512)         │       1,049,088 │ conv5_block1_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_1_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block2_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_1_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block2_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_2_conv (Conv2D)  │ (None, 7, 7, 512)         │       2,359,808 │ conv5_block2_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_2_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block2_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_2_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block2_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_3_conv (Conv2D)  │ (None, 7, 7, 2048)        │       1,050,624 │ conv5_block2_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_3_bn             │ (None, 7, 7, 2048)        │           8,192 │ conv5_block2_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_add (Add)        │ (None, 7, 7, 2048)        │               0 │ conv5_block1_out[0][0],    │
# │                               │                           │                 │ conv5_block2_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block2_out (Activation) │ (None, 7, 7, 2048)        │               0 │ conv5_block2_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_1_conv (Conv2D)  │ (None, 7, 7, 512)         │       1,049,088 │ conv5_block2_out[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_1_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block3_1_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_1_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block3_1_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_2_conv (Conv2D)  │ (None, 7, 7, 512)         │       2,359,808 │ conv5_block3_1_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_2_bn             │ (None, 7, 7, 512)         │           2,048 │ conv5_block3_2_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_2_relu           │ (None, 7, 7, 512)         │               0 │ conv5_block3_2_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_3_conv (Conv2D)  │ (None, 7, 7, 2048)        │       1,050,624 │ conv5_block3_2_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_3_bn             │ (None, 7, 7, 2048)        │           8,192 │ conv5_block3_3_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_add (Add)        │ (None, 7, 7, 2048)        │               0 │ conv5_block2_out[0][0],    │
# │                               │                           │                 │ conv5_block3_3_bn[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv5_block3_out (Activation) │ (None, 7, 7, 2048)        │               0 │ conv5_block3_add[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d      │ (None, 2048)              │               0 │ conv5_block3_out[0][0]     │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 2048)              │               0 │ global_average_pooling2d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 4)                 │           8,196 │ dropout[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 23,595,908 (90.01 MB)
#  Trainable params: 23,542,788 (89.81 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
callbacks = [ModelCheckpoint('.mdl_wts.keras', monitor='val_loss',mode='min',verbose=1, save_best_only=True),ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=1, mode='min', min_lr=0.00000000001)]

# %%
train_len = len(x_train)
val_len = len(x_val)
print("-----------Training Data length-----------------")
print(train_len)

print("-----------Validation Data length-----------------")
print(val_len)
# Out:
# -----------Training Data length-----------------
# 4569
# -----------Validation Data length-----------------
# 1143

# %%
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),validation_data = (x_val,y_val),epochs = 50,callbacks = callbacks)
# Out:
# C:\Users\Shruti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7648 - loss: 0.5959
# Epoch 1: val_loss improved from None to 3.73454, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 799s 10s/step - accuracy: 0.8720 - loss: 0.3346 - val_accuracy: 0.2283 - val_loss: 3.7345 - learning_rate: 1.0000e-04
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9685 - loss: 0.0927
# Epoch 2: val_loss did not improve from 3.73454
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 680s 9s/step - accuracy: 0.9733 - loss: 0.0787 - val_accuracy: 0.2336 - val_loss: 4.7352 - learning_rate: 1.0000e-04
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9851 - loss: 0.0463
# Epoch 3: val_loss did not improve from 3.73454
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 669s 9s/step - accuracy: 0.9864 - loss: 0.0430 - val_accuracy: 0.2283 - val_loss: 4.2609 - learning_rate: 1.0000e-04
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.9903 - loss: 0.0326
# Epoch 4: val_loss did not improve from 3.73454
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1269s 18s/step - accuracy: 0.9930 - loss: 0.0231 - val_accuracy: 0.2266 - val_loss: 4.4480 - learning_rate: 3.0000e-05
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 0.9964 - loss: 0.0145
# Epoch 5: val_loss did not improve from 3.73454
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2060s 29s/step - accuracy: 0.9956 - loss: 0.0147 - val_accuracy: 0.2493 - val_loss: 4.1016 - learning_rate: 3.0000e-05
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9974 - loss: 0.0098
# Epoch 6: val_loss did not improve from 3.73454
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9961 - loss: 0.0111 - val_accuracy: 0.2318 - val_loss: 4.0545 - learning_rate: 9.0000e-06
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9987 - loss: 0.0073
# Epoch 7: val_loss did not improve from 3.73454
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 634s 9s/step - accuracy: 0.9982 - loss: 0.0065 - val_accuracy: 0.2371 - val_loss: 4.1543 - learning_rate: 9.0000e-06
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9996 - loss: 0.0049
# Epoch 8: val_loss did not improve from 3.73454
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 639s 9s/step - accuracy: 0.9996 - loss: 0.0049 - val_accuracy: 0.2695 - val_loss: 4.0104 - learning_rate: 2.7000e-06
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.9987 - loss: 0.0066
# Epoch 9: val_loss improved from 3.73454 to 3.44163, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1142s 16s/step - accuracy: 0.9985 - loss: 0.0060 - val_accuracy: 0.3088 - val_loss: 3.4416 - learning_rate: 2.7000e-06
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.9985 - loss: 0.0082
# Epoch 10: val_loss improved from 3.44163 to 2.63773, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1383s 19s/step - accuracy: 0.9987 - loss: 0.0063 - val_accuracy: 0.3972 - val_loss: 2.6377 - learning_rate: 2.7000e-06
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9988 - loss: 0.0061
# Epoch 11: val_loss improved from 2.63773 to 1.85854, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 640s 9s/step - accuracy: 0.9982 - loss: 0.0067 - val_accuracy: 0.5066 - val_loss: 1.8585 - learning_rate: 2.7000e-06
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9991 - loss: 0.0059
# Epoch 12: val_loss improved from 1.85854 to 1.30283, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 636s 9s/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 0.6325 - val_loss: 1.3028 - learning_rate: 2.7000e-06
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9983 - loss: 0.0050
# Epoch 13: val_loss improved from 1.30283 to 0.82257, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 683s 9s/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.7585 - val_loss: 0.8226 - learning_rate: 2.7000e-06
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - accuracy: 0.9987 - loss: 0.0042
# Epoch 14: val_loss improved from 0.82257 to 0.48771, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2266s 32s/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.8390 - val_loss: 0.4877 - learning_rate: 2.7000e-06
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9986 - loss: 0.0043
# Epoch 15: val_loss improved from 0.48771 to 0.26811, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 634s 9s/step - accuracy: 0.9989 - loss: 0.0045 - val_accuracy: 0.9265 - val_loss: 0.2681 - learning_rate: 2.7000e-06
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9998 - loss: 0.0025
# Epoch 16: val_loss improved from 0.26811 to 0.17146, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 637s 9s/step - accuracy: 0.9996 - loss: 0.0030 - val_accuracy: 0.9650 - val_loss: 0.1715 - learning_rate: 2.7000e-06
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 17: val_loss improved from 0.17146 to 0.13252, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 636s 9s/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9781 - val_loss: 0.1325 - learning_rate: 2.7000e-06
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9993 - loss: 0.0032
# Epoch 18: val_loss improved from 0.13252 to 0.11656, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 643s 9s/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9808 - val_loss: 0.1166 - learning_rate: 2.7000e-06
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9986 - loss: 0.0049
# Epoch 19: val_loss improved from 0.11656 to 0.10931, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 632s 9s/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9790 - val_loss: 0.1093 - learning_rate: 2.7000e-06
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9996 - loss: 0.0024
# Epoch 20: val_loss improved from 0.10931 to 0.10677, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 688s 9s/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9799 - val_loss: 0.1068 - learning_rate: 2.7000e-06
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.9991 - loss: 0.0046
# Epoch 21: val_loss improved from 0.10677 to 0.10210, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1230s 17s/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9799 - val_loss: 0.1021 - learning_rate: 2.7000e-06
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9998 - loss: 0.0023
# Epoch 22: val_loss improved from 0.10210 to 0.10184, saving model to .mdl_wts.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 633s 9s/step - accuracy: 0.9998 - loss: 0.0026 - val_accuracy: 0.9808 - val_loss: 0.1018 - learning_rate: 2.7000e-06
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9999 - loss: 0.0027
# Epoch 23: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 633s 9s/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 0.9799 - val_loss: 0.1025 - learning_rate: 2.7000e-06
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9988 - loss: 0.0041
# Epoch 24: val_loss did not improve from 0.10184
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 632s 9s/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.9799 - val_loss: 0.1044 - learning_rate: 2.7000e-06
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 25: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9808 - val_loss: 0.1030 - learning_rate: 8.1000e-07
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9986 - loss: 0.0040
# Epoch 26: val_loss did not improve from 0.10184
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 694s 9s/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9799 - val_loss: 0.1033 - learning_rate: 8.1000e-07
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9996 - loss: 0.0034
# Epoch 27: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 635s 9s/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9799 - val_loss: 0.1031 - learning_rate: 2.4300e-07
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9998 - loss: 0.0026
# Epoch 28: val_loss did not improve from 0.10184
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9996 - loss: 0.0031 - val_accuracy: 0.9790 - val_loss: 0.1028 - learning_rate: 2.4300e-07
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9999 - loss: 0.0018
# Epoch 29: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 632s 9s/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9799 - val_loss: 0.1025 - learning_rate: 7.2900e-08
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9982 - loss: 0.0048
# Epoch 30: val_loss did not improve from 0.10184
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 681s 9s/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.9799 - val_loss: 0.1026 - learning_rate: 7.2900e-08
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9993 - loss: 0.0039
# Epoch 31: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 635s 9s/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9799 - val_loss: 0.1028 - learning_rate: 2.1870e-08
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9973 - loss: 0.0056
# Epoch 32: val_loss did not improve from 0.10184
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 677s 9s/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9808 - val_loss: 0.1027 - learning_rate: 2.1870e-08
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9981 - loss: 0.0041
# Epoch 33: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 634s 9s/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9799 - val_loss: 0.1031 - learning_rate: 6.5610e-09
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9980 - loss: 0.0033
# Epoch 34: val_loss did not improve from 0.10184
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.968299789822936e-09.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 680s 9s/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9799 - val_loss: 0.1027 - learning_rate: 6.5610e-09
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9990 - loss: 0.0032
# Epoch 35: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 645s 9s/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9799 - val_loss: 0.1027 - learning_rate: 1.9683e-09
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9980 - loss: 0.0047
# Epoch 36: val_loss did not improve from 0.10184
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.904899236242044e-10.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 637s 9s/step - accuracy: 0.9996 - loss: 0.0029 - val_accuracy: 0.9790 - val_loss: 0.1027 - learning_rate: 1.9683e-09
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9989 - loss: 0.0034
# Epoch 37: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9799 - val_loss: 0.1031 - learning_rate: 5.9049e-10
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9991 - loss: 0.0047
# Epoch 38: val_loss did not improve from 0.10184
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.771469804179304e-10.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 634s 9s/step - accuracy: 0.9993 - loss: 0.0035 - val_accuracy: 0.9790 - val_loss: 0.1025 - learning_rate: 5.9049e-10
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9980 - loss: 0.0061
# Epoch 39: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9985 - loss: 0.0039 - val_accuracy: 0.9790 - val_loss: 0.1026 - learning_rate: 1.7715e-10
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9989 - loss: 0.0046
# Epoch 40: val_loss did not improve from 0.10184
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9996 - loss: 0.0027 - val_accuracy: 0.9790 - val_loss: 0.1029 - learning_rate: 1.7715e-10
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9983 - loss: 0.0047
# Epoch 41: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 680s 9s/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9799 - val_loss: 0.1026 - learning_rate: 5.3144e-11
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9993 - loss: 0.0047
# Epoch 42: val_loss did not improve from 0.10184
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5943227987813556e-11.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9799 - val_loss: 0.1027 - learning_rate: 5.3144e-11
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9998 - loss: 0.0031
# Epoch 43: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 631s 9s/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 0.9790 - val_loss: 0.1027 - learning_rate: 1.5943e-11
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9986 - loss: 0.0061
# Epoch 44: val_loss did not improve from 0.10184
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-11.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 683s 9s/step - accuracy: 0.9987 - loss: 0.0061 - val_accuracy: 0.9790 - val_loss: 0.1028 - learning_rate: 1.5943e-11
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9999 - loss: 0.0028
# Epoch 45: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 632s 9s/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 0.9799 - val_loss: 0.1029 - learning_rate: 1.0000e-11
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9986 - loss: 0.0034
# Epoch 46: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 632s 9s/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9799 - val_loss: 0.1031 - learning_rate: 1.0000e-11
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9991 - loss: 0.0030
# Epoch 47: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 633s 9s/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9799 - val_loss: 0.1028 - learning_rate: 1.0000e-11
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9983 - loss: 0.0045
# Epoch 48: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 630s 9s/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9799 - val_loss: 0.1029 - learning_rate: 1.0000e-11
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9989 - loss: 0.0034
# Epoch 49: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 629s 9s/step - accuracy: 0.9982 - loss: 0.0045 - val_accuracy: 0.9790 - val_loss: 0.1025 - learning_rate: 1.0000e-11
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9993 - loss: 0.0023
# Epoch 50: val_loss did not improve from 0.10184
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 629s 9s/step - accuracy: 0.9989 - loss: 0.0029 - val_accuracy: 0.9799 - val_loss: 0.1024 - learning_rate: 1.0000e-11

# %%
from tensorflow.keras.models import load_model
model = load_model('.mdl_wts.keras')
model.save('C:/Users/Shruti/Downloads/brain_tumor/modelres50.h5')

model = load_model('C:/Users/Shruti/Downloads/brain_tumor/modelres50.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Plot the Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
plt.show()

#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
plt.show()

# %%
loss,acc = model.evaluate(x_test,y_test)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9825 - loss: 0.0727

# %%
import seaborn as sns
predicted_classes = np.argmax(model.predict(x_test), axis = 1)
print(classification_report(np.argmax(y_test,axis=1), predicted_classes,target_names=['glioma','meningioma','no_tumor','pituitary']))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 165s 4s/step
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.98      0.98       300
#   meningioma       0.98      0.96      0.97       306
#     no_tumor       0.99      0.99      0.99       405
#    pituitary       0.99      0.99      0.99       300
#
#     accuracy                           0.98      1311
#    macro avg       0.98      0.98      0.98      1311
# weighted avg       0.98      0.98      0.98      1311

# %%
import itertools
pred_Y = model.predict(x_test, batch_size = 8, verbose = True)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    target_names=['glioma','meningioma','no_tumor','pituitary']

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test, batch_size=8)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(pred_Y,axis = 1)
# Convert validation observations to one hot vectors
# compute the confusion matrix
rounded_labels=np.argmax(y_test, axis=1)
confusion_mtx = confusion_matrix(rounded_labels, Y_pred_classes)



# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(4))
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step

# %%
y_hat = model.predict(x_test)

# define text labels
target_labels = ['glioma','meningioma','no_tumor','pituitary']

# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=12, replace=False)):
    ax = fig.add_subplot(4,4, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(target_labels[pred_idx], target_labels[true_idx]),
                 color=("blue" if pred_idx == true_idx else "orange"))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 150s 4s/step
